# %% [markdown]
# **Create a Hangman Game**
#
# Click <a href="https://en.wikipedia.org/wiki/Hangman_(game)" target="_blank">here</a> to learn how to play, or to simply get a refresher for how the game works.
#
# Create an object-orient program that works exactly as the Wikipedia page suggests.
#
# Given, are all of the classes to build out the game. While extremely helpful, please note that this may be an ineffective method of building your program, because it hinders how one you would naturally build a program in your own way if they were left to figure it out for themselves.
#
# **How to build the program**
# * When you start the game, you will need to select a random word from a list of at least 10 words (You have full control over which words you want to use for you program). This will be your secret word. Your secret word will be represented in the program as a group of underscores. For as long as the word is, you should also have that many underscores.
#
# * Once the word is selected, your game will commence. Perform a Google search to figure out how to select a random word from a list using Python.<br>
# **Hint** There's package you can import into your application that does this for you.
#
# * The end user will have a total of 8 chances to guess the correct letter from the secret word. If the end user makes 8 incorrect guesses, the game will end.
#
# * As you guess the correct letters, the letters you have guess will then take place of the underscores that letter represents. <br>
# **For Example**: If your secret word is 'watermelon' and  so far you have guessed the letters 'a' and 'e', the word you're trying to guess will appear as follows: _ a _ e _ _ e _ _ _.<br>
# **Keep in mind** that if you guess a letter that appears more than once in your secret word, make sure that the letter is populated anywhere that letter would be.

# %%
# Object-Oriented Programming Method

import random
from IPython.display import clear_output

#Create the Object for Hangman
class Hangman():
    #def __init__(self, secret_word, guess_letter, guesses_taken, guesses_left=8):
        #self.secret_word = secret_word
        #self.guess_letter = guess_letter
        #self.guesses_taken = guesses_taken
        #self.guesses_left = guesses_left
        
    def __init__(self, guesses_left=8):
        self.guesses_left = guesses_left
        
        
    def main(self):
        #first function is to randomly grab a word from the secretword list
        guesses_left = 8
        guesses_taken = 0
        guesses_left = guesses_left - guesses_taken
        words = ["werewolf", "vampire", "thunderbird", "minotaur", "hellhound", "skinwalker", "ghost", "poltergeist" "gremlin", "bigfoot",  "bigfoot"]
        secretword = list(random.choice(words))
        secretwordstring = "".join(secretword)
        underscore = []
        guessed =[]
        print("Welcome to Hangsaman. You have 8 chances to guess letters in the SUPER SECRET WORD. If you know the word,\
you can simply type in the word to guess it.")
        for letter in range(len(secretword)):
            underscore.append("_ ")
        playing = True
        
        while True:
            if guesses_left > 0:
                playing = True
            else:
                clear_output()
                playing = False
                print("You're out of guesses! The SUPER SECRET WORD was: {}.".format(secretwordstring))
                break
            secretwordstring = "".join(secretword)
            guess_letter = str(input("Guess a single letter! ")).lower()
            guesses_taken +=1
            guesses_left -= 1
            print("Your guess was {}. ".format(guess_letter))
            if guess_letter.isalpha() == False:
                clear_output()
                print("That's not a letter, and it still counts as a turn. You've guessed {} and have {} guesses left {}.".format(guessed, guesses_left, underscore))
            elif len(guess_letter) != 1 and guess_letter != secretwordstring:
                clear_output()
                print("That's more than one character, but it still counts as a turn. You've guessed {} and have {} guesses left {}.".format(guessed, guesses_left, underscore))
            elif guess_letter == secretwordstring:
                clear_output()
                print("You guessed it! The secret word was {}. YOU WIN!!!!!".format(secretwordstring))
                playing = False
                break
            elif guess_letter.isalpha() == True:
                clear_output()
                guessed.append(guess_letter)
                for letter in secretword:
                    if guess_letter == letter:
                        for index,l in enumerate(secretwordstring):
                            if l is letter:
                                underscore[index] = l
                        #print(indexpoint)
                        #del underscore[indexpoint]
                        #underscore.insert(indexpoint, letter)
                        print("{} This is what you have to guess for. You have {} chances left and so far you've guessed {} ".format(underscore, guesses_left, guessed))
                        break
                        clear_output()
                    elif guess_letter not in secretword:
                        clear_output()
                        print("Nope, {} isn't in the Super Secret Word. So far you've guessed {} and you have {} turns left. {}".format(guess_letter, guessed, guesses_left, underscore))
                        break
                        clear_output()
                
            elif guess_letter.lower() == secretwordstring:
                clear_output()
                print("You guessed it! The secret word was {}. YOU WIN!!!!!".format(secretword))
                playing = False
                break
                

        #then I have to create a random list of secretwords and randomly pick one. 
        #then I need to put clearfix in the right spots. 
        
        #so right now I'm building this functionally instead of with OOP. I'm going to continue this with functional
        #programming and then re-do it below as OOP. That should just be splitting up everything that's
        #happening in the function to different named methods, like the shopping cart OOP. Look to that for reference.

#                         indexpoint = secretword.index(letter)
    
# Create main function here - This will run our program and create/instantiate our Hangman class
hanga = Hangman()
hanga.main()
